# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pymongo import MongoClient
from pandas.io.json import json_normalize
import re
from pprint import pprint
import string

# %% [markdown]
# # ============================================ renmin fake

# %%
r = pd.read_csv('renmin.csv')
r.drop(['Unnamed: 0', '_id_y'], axis=1, inplace=True)
r.drop_duplicates(inplace=True)
r.drop(['crawl_time_x', 'crawl_time_y', 'created_at', 'org_wbid_uid', 'repost_user_id'], axis=1, inplace=True)
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6420 entries, 0 to 7857
# Data columns (total 17 columns):
# _id_x                 6420 non-null int64
# authentication        1088 non-null object
# birthday              5027 non-null object
# brief_introduction    5676 non-null object
# city                  2543 non-null object
# fans_num              6420 non-null int64
# follows_num           6420 non-null int64
# gender                6412 non-null object
# labels                2522 non-null object
# nick_name             6412 non-null object
# province              6412 non-null object
# sentiment             208 non-null object
# sex_orientation       145 non-null object
# tweets_num            6420 non-null int64
# vip_level             6412 non-null object
# content               6420 non-null object
# repost_device         4962 non-null object
# dtypes: int64(4), object(13)
# memory usage: 902.8+ KB

# %%
r.head()
# Out:
#         _id_x authentication    birthday brief_introduction city  fans_num  \
# 0  2849560641            NaN         巨蟹座    人生在世，谁都会吃屎，但是别嚼   成都        84
# 1  2849560641            NaN         巨蟹座    人生在世，谁都会吃屎，但是别嚼   成都        84
# 2  2315828514            NaN  1900-12-29                NaN  NaN        32
# 3  2315828514            NaN  1900-12-29                NaN  NaN        32
# 4  6459746842            NaN         NaN                NaN  NaN         3
#
#    follows_num gender labels     nick_name province sentiment sex_orientation  \
# 0          163      女     美食          芒果奶熙       四川       NaN             NaN
# 1          163      女     美食          芒果奶熙       四川       NaN             NaN
# 2           61      女     旅游       心随纸鸢自在飞       上海       NaN             NaN
# 3           61      女     旅游       心随纸鸢自在飞       上海       NaN             NaN
# 4          104      男    NaN  用户6459746842       其他       NaN             NaN
#
#    tweets_num vip_level                                            content  \
# 0         114       未开通  芒果奶熙:尊重是一切最基本的遵循//@罗云熙Leo:尊重是一切最基本的遵循 赞[0] 03月...
# 1         114       未开通  芒果奶熙:尊重是一切最基本的遵循//@罗云熙Leo:尊重是一切最基本的遵循 赞[0] 03月...
# 2        1565        3级  心随纸鸢自在飞:有你@罗云熙Leo 相伴，不惧风雨。快来为TA应援吧  //@罗云熙Leo:...
# 3        1565        3级  心随纸鸢自在飞:有你@罗云熙Leo 相伴，不惧风雨。快来为TA应援吧  //@罗云熙Leo:...
# 4           2       未开通  用户6459746842://@六小龄童:自取其辱 赞[0] 2018-12-20 15:5...
#
#      repost_device
# 0    来自 iPhone客户端
# 1    来自 iPhone客户端
# 2         来自明星ALL榜
# 3         来自明星ALL榜
# 4  来自荣耀Note10 大屏旗舰

# %%
r_yonghu = list(r.loc[((r['nick_name'].str.contains('^用户', na=False)) & (r['vip_level'] == '未开通')), 'nick_name'].unique())
r_yonghu
# Out:
# ['用户6459746842',
#  '用户6841613130',
#  '用户6178461401',
#  '用户6673393309',
#  '用户6291509410',
#  '用户6494032131',
#  '用户5616685914',
#  '用户3948702009',
#  '用户5667874413',
#  '用户6623674717']

# %%
r_fake = r[((r['follows_num']<=5)|(r['fans_num']<=5))&
                 (r['birthday'].isna())&
                 (r['city'].isna())&
                (r['sentiment'].isna())&
                (r['sex_orientation'].isna())&
                (r['brief_introduction'].isna())].copy()
r_fake.drop_duplicates(inplace=True)
r_fake.shape
# Out:
# (10, 17)

# %%
r_fake = list(r_fake['nick_name'].unique())
r_fake
# Out:
# ['用户6459746842',
#  '我觉得你不行丶',
#  '用户6291509410',
#  '用户6494032131',
#  'Tony的战衣w',
#  '用户5616685914',
#  '晓芸在江湖',
#  '丹巴吉美',
#  '蜻蜓FM音乐课代表']

# %%
r_digit = r[r['nick_name'].str.contains(r'\d+$', na=False)].copy().drop_duplicates()
r_digit.shape
# Out:
# (370, 17)

# %%
r_digit = list(r_digit['nick_name'].unique())
r_digit
# Out:
# ['用户6459746842',
#  '莎莎的梦11',
#  '用户6841613130',
#  '女汉子完美585',
#  '傅-1127',
#  '腾飞的骏马48761',
#  '叶伶886',
#  '用户6178461401',
#  '心兴星7',
#  '小棚子1017',
#  '哈哈就是我699',
#  '要开心鸭1688',
#  'Seoman1999',
#  'July720',
#  'enough_97735',
#  '安静待97',
#  '艺神66666',
#  '么么哒闯天涯009',
#  '山花精1208',
#  '下凡的天使0313',
#  '磨磨叽叽77',
#  'Demian0215',
#  '小草的爱6452491085',
#  '有点纠结的_527',
#  '爱幂不解释_24777',
#  '羊羊羊200909',
#  'Doraemon753',
#  'Dear-佛系美少女88',
#  '万小鹿1997',
#  '遇见pp叫a1',
#  '偷吃芒果111',
#  'DUYIYAN11',
#  '且行且珍惜74594',
#  '咕噜咕噜兔7',
#  'Love如果0828',
#  'yhm-1987',
#  'ww20160911',
#  '随便看看就好24',
#  '超级源-LBY685',
#  '不知名的小学生575',
#  '我鱼贼啦6',
#  'Purple_0713',
#  '旺仔的小馒头0131',
#  '谁的青春乱了流年_97621',
#  'Jessica无所谓_1988',
#  '红莲1007',
#  'Peonypeony521',
#  '与尤长靖一起有长进的2019',
#  '弯呢菜菜56286',
#  '夏天的天4711',
#  '许豆豆9',
#  'yumi0710',
#  '密码不能忘55',
#  '别来关注886',
#  '鱼说1979',
#  '婧婧婧婧婧婧2',
#  '李妮12',
#  '盗号好玩吗20151223',
#  '粥喵吃鲸鱼123',
#  '柠檬酸甜酱123',
#  '杰2c1',
#  'isghkshdb14',
#  '李昇炫的大米1',
#  '晓辉0106',
#  '叶莉9699',
#  '最好的你112233',
#  '柠檬柚子921',
#  '小九NiNe99',
#  '册册_7',
#  '不要真情实感411',
#  '橙子味仙女520',
#  '现充积分87',
#  'Rachelzhang0227',
#  '大白44444',
#  'TS-777',
#  '小甜豆420',
#  'Snowflake07',
#  'lucarmen90',
#  '春困1',
#  'Pinklily0',
#  '好个秋515',
#  '柒悻而77',
#  '當時只道是尋常_95',
#  'Samantha-222',
#  '猫扑233',
#  '易老头儿的老伴儿楠楠062028',
#  '聽说2626',
#  '六月米米865',
#  '杜华我是你爹2333',
#  '海天之春2019',
#  '有人说啊有人说26',
#  '阳羡雪芽1019',
#  '易烊千玺B001',
#  '西柚少女77',
#  '00一00一00',
#  '独木舟201606',
#  '新喜旧爱_7',
#  '等等等等等等等1920',
#  'Pathosis6518840571',
#  '4-forest-9',
#  'sunny妮212',
#  '团宠921',
#  '海海海海海玉007',
#  'vennisa78',
#  '倩er0826',
#  'dd_31313',
#  'GRANDBLUE0921',
#  '用户6673393309',
#  'K-513',
#  'CHENYU96731',
#  'heyme005',
#  '二十个石榴06131128',
#  '咕叽咕叽钻进你的怀里7',
#  '你好小姑凉88666',
#  '双鱼座的木木啊789',
#  '带三级头的27',
#  '张小梦梦720',
#  '如果也可以9',
#  '绿夏114',
#  '小屁孩1689',
#  '岳溪201701',
#  'FWEVOLCC0802',
#  '用户6291509410',
#  '小朋友的2019',
#  '起名废V5',
#  '尾声夙4479',
#  '小小号198611',
#  '月落无声11',
#  '他叫我NO_9',
#  'Reply2008',
#  '依然n11',
#  '念只念那相遇的一瞬间1128',
#  'SK-0722',
#  '一颗小橘子呀416',
#  '-手机用户070770777',
#  '晨光久久9',
#  '知歡喜19821220',
#  '皮蛋瘦肉粥199106',
#  'th啦啦_64997',
#  'yoona512',
#  'unparalleledgirls22035',
#  '用户6494032131',
#  '77tomato77',
#  'MMMicky3',
#  '墙头一大堆2017',
#  'Xback-浅忆梦微凉1007',
#  '一心向橘880416',
#  '还没想好呀1226',
#  'GDgragon2037',
#  '天使爱love0',
#  '洛洛大方123',
#  '宇宙胆小鬼22',
#  '55思思11',
#  'YoukyWu567',
#  'suzushi_0303',
#  '忆安869',
#  '放飞梦想0038',
#  '网友小丽0805',
#  '添福啵的妈姆2023',
#  '小茜茜22167',
#  '小脑斧0108',
#  '雨滴-2012',
#  '沉沦他的美1021',
#  'JessieChao_928',
#  '袁秃秃0秃噜秃0',
#  '家有小米1003',
#  'xueyuan8204',
#  '夏日倾情0718',
#  '我在等风也等你87',
#  'MissCookie713',
#  '朱正廷-iris-666',
#  '你好甜喔11',
#  '08橘子汽水24',
#  '远辰365',
#  'BetterPink01',
#  'pasttime2018',
#  '定风波空荡荡018',
#  '_real404922',
#  '洛洛洛樱0303',
#  '一首不为谁而做的歌0806',
#  '海深不蓝_2019',
#  'NN-68',
#  '鹿公子LH7',
#  '用户5616685914',
#  '我家王俊凯有9对2象1',
#  '周周仙777',
#  'FFEN_921',
#  '悠悠0629',
#  '好好de贝儿00',
#  '为什么昵称不能用啊2333',
#  'Au1_0',
#  '凝芯2017',
#  '东条希是我老婆233',
#  '鲸鱼宝宝最可爱123',
#  '用户3948702009',
#  'T陶陶22',
#  '廖撩1011',
#  '哈哈哈哈乘3',
#  '全城戒备1347',
#  '抹茶_2019',
#  '巴黎夜雨1030',
#  '西柚姐姐919',
#  '久处仍怦然123',
#  '红叶李1999',
#  '抽風姬23333',
#  'Jojo王1207',
#  '用户5667874413',
#  '坤坤有点困困y7',
#  '一朵飘过的浮云007',
#  '谷若姝GRS01221128',
#  'Lovingxing1007',
#  '大头柠檬886',
#  'iiillll111',
#  '烊小烊1128',
#  '媚儿0420',
#  '凤淡云轻66',
#  '我写我芯1985',
#  'Caspar687',
#  '梦蝶-201309',
#  '拨云见日8891',
#  'bloom233',
#  '敏大大会发光1997',
#  '舞影零乱76',
#  '睡不饱的西瓜233',
#  '今天吃麻辣烫了Ya_0426',
#  '正在努力的一只ikun6',
#  '1993年3月10',
#  'TS今天跑步了吗1',
#  '玺-遇28',
#  '放4的4',
#  '酒窝骗子张艺兴1007',
#  '05·30',
#  '红衣配白裳2015',
#  '气球1',
#  'wodechina3',
#  'Wanderlust2224',
#  'Maybes99',
#  'haixingba777',
#  '我要瘦我要瘦12',
#  '芦荟爱发呆2019',
#  'pipi5200921',
#  '栗栗栗95',
#  '雨韻兒143',
#  'Mentholatum333',
#  'Daisy14121',
#  '半生素衣1027',
#  '--20055',
#  '星星泪的天空20',
#  'SHAYAYI1',
#  'illusion20010901',
#  'YOUNG07651',
#  'unagrulladepapel4',
#  '顺逆毛365',
#  'simon198003',
#  'YOLO_1204',
#  '依依Eva0',
#  '奈何是你2000',
#  '默数54321',
#  '我搞到真的了8',
#  '乱码3222',
#  '楠楠是我小叔子1128',
#  '龙一鸣24',
#  '紫语6688',
#  '用于199419912014',
#  'dyfp5',
#  '安小朵201303',
#  'danny923478',
#  '穷奇7788',
#  '卡米亚的小迷妹10769',
#  'eternalsunshine852',
#  '用户6623674717',
#  '爱睡觉的猪123456',
#  '白色74632',
#  '可可乐1244',
#  '一柔花开88',
#  'justbefriends1',
#  '豆豆forever4',
#  '爱因思叹V2',
#  '是日夏茗2029',
#  '小董就是我越来越好啊0511',
#  'dd离歌88',
#  '乘风破浪8866',
#  '我想一夜暴富699',
#  '奔跑的宝贝乐乐11',
#  '月光宝盒0214',
#  'SeanJH597',
#  '嘉有长靖1994',
#  'Sssharon28',
#  'fg74608',
#  '有梦想的人49',
#  'nesay1995',
#  'ELPSYCONGROO5100',
#  '学wy3',
#  '杞人忧天233',
#  '王大哥_66',
#  '榴莲味的布丁1128',
#  '愉快156',
#  'weii92',
#  '一只傻阿文2015',
#  'Kakk9',
#  'hey敏儿_027',
#  '留白的执念1020',
#  '李东海的小迷妹12138',
#  '春风十里不如你1104',
#  'yangchao_1211',
#  'HcuiY3003',
#  '蒲公英9911',
#  '九九420420',
#  'cici_198008',
#  '玉米排骨汤201806',
#  'Special1102',
#  '啊哈耶123',
#  '克里斯-小予妈5959',
#  '假如可以假如2',
#  '请你喜欢我8',
#  '呆的二次方1933',
#  'Mysweettea99',
#  'KIRSTY917',
#  '冷无缺2333',
#  '金kai88',
#  '好人6196589767',
#  '我是女王家的小7',
#  '今天爱易烊千玺了吗1128',
#  '段段呀030',
#  'DoubleKim4',
#  'ln_0423',
#  '庆ioidog123',
#  'Kathleen阿琪08256',
#  'tinaseven61',
#  'hkx130',
#  '不是段矞1998',
#  '赵满堂823',
#  'AE小土豆qwq三木木13',
#  '待君归来waiting-for-5',
#  '木槿cecilia1',
#  '卉3104',
#  '风继续吹想念339']

# %%
r['nick_name'].fillna(value='noname')
r_eng_char = list(r.loc[r['nick_name'].map(lambda v: any(char in v for char in string.punctuation)), 'nick_name'].unique())
r_eng_char
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-312-906fd0728f57> in <module>()
#       1 r['nick_name'].fillna(value='noname')
# ----> 2 r_eng_char = list(r.loc[r['nick_name'].map(lambda v: any(char in v for char in string.punctuation)), 'nick_name'].unique())
#       3 r_eng_char
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    2996         """
#    2997         new_values = super(Series, self)._map_values(
# -> 2998             arg, na_action=na_action)
#    2999         return self._constructor(new_values,
#    3000                                  index=self.index).__finalize__(self)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1002
#    1003         # mapper is a function
# -> 1004         new_values = map_f(values, mapper)
#    1005
#    1006         return new_values
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-312-906fd0728f57> in <lambda>(v)
#       1 r['nick_name'].fillna(value='noname')
# ----> 2 r_eng_char = list(r.loc[r['nick_name'].map(lambda v: any(char in v for char in string.punctuation)), 'nick_name'].unique())
#       3 r_eng_char
#
# <ipython-input-312-906fd0728f57> in <genexpr>(.0)
#       1 r['nick_name'].fillna(value='noname')
# ----> 2 r_eng_char = list(r.loc[r['nick_name'].map(lambda v: any(char in v for char in string.punctuation)), 'nick_name'].unique())
#       3 r_eng_char
#
# TypeError: argument of type 'float' is not iterable

# %%
r_chi_char = []
for c in charlist:
    tmp = r[r['nick_name'].str.contains(c, na=False)].copy().drop_duplicates()
    names = list(tmp['nick_name'].unique())
    r_chi_char += names
r_chi_char = list(set(r_chi_char))
r_chi_char
# Out:
# ['一片绯色的鱼丶',
#  '晓不语丶',
#  '超丨甜',
#  '鑫xin灬灬',
#  '小小小兔酱丶',
#  '八十一哟丶',
#  '豆丶豆豆豆豆子',
#  '毕丨之',
#  '夜神樱良丷',
#  '二艹_你是我的奇迹',
#  'Angie丶甜',
#  '王足各口阝可',
#  '茕茕白兔丨朱一龙',
#  '丫丶旧-',
#  'Regina丨梁只赢',
#  '怼怼呐丨毕竟又长大一岁啦',
#  '惊鸿照影来彡',
#  'Imirror丶d',
#  'Oni丨',
#  'a丶sHero',
#  '我儿今天解约了吗丶',
#  '小芋圆罒3罒',
#  '大丈夫萌呆乃丶丶丶',
#  '我觉得你不行丶',
#  '女王丶病娇',
#  '威崽丶']

# %%
r_bd = list(r.loc[r['birthday'].str.contains('^201', na=False), 'nick_name'].unique())
len(r_bd)
# Out:
# 198

# %%
r_fanhui = list(r.loc[((r['content'].str.contains('^返回')) | (r['content'].str.contains('//'))) 
                                           & (r['brief_introduction'].isna()), 'nick_name'].unique())
len(r_fanhui)
# Out:
# 148

# %%
r_names = list(set(r_yonghu + r_fake + r_digit + r_chi_char + r_bd + r_fanhui))
len(r_names)
# Out:
# 672

# %% [markdown]
# # ============================================ zhang fake

# %%
z = pd.read_csv('zhang_merged.csv')
z.drop(['Unnamed: 0', '_id_y'], axis=1, inplace=True)
z.drop_duplicates(inplace=True)
z.drop(['crawl_time_x', 'crawl_time_y', 'created_at', 'org_wbid_uid', 'repost_user_id'], axis=1, inplace=True)

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7308 entries, 0 to 14042
# Data columns (total 17 columns):
# _id_x                 7308 non-null int64
# authentication        610 non-null object
# birthday              3882 non-null object
# brief_introduction    2758 non-null object
# city                  2468 non-null object
# fans_num              7307 non-null float64
# follows_num           7307 non-null float64
# gender                7308 non-null object
# labels                791 non-null object
# nick_name             7308 non-null object
# province              7308 non-null object
# sentiment             326 non-null object
# sex_orientation       60 non-null object
# tweets_num            7307 non-null float64
# vip_level             7308 non-null object
# content               7308 non-null object
# repost_device         580 non-null object
# dtypes: float64(3), int64(1), object(13)
# memory usage: 1.0+ MB

# %%
# ============================================ nick name
z_yonghu = z[z['nick_name'].str.contains('^用户', na=False)].copy().drop_duplicates()

# %%
z_yonghu['_id_x'].value_counts().shape
# Out:
# (91,)

# %%
z_yonghu = list(z_yonghu['nick_name'].unique())
z_yonghu
# Out:
# ['用户6751917874',
#  '用户6750984191',
#  '用户6751965975',
#  '用户6751021484',
#  '用户6736814689',
#  '用户6900763324',
#  '用户6765418070',
#  '用户6827930453',
#  '用户6910108534',
#  '用户6828412357',
#  '用户6660880069',
#  '用户6883315543',
#  '用户6743016204',
#  '用户6825553246',
#  '用户6739943318',
#  '用户6730618127',
#  '用户6828508506',
#  '用户6825485780',
#  '用户6919882792',
#  '用户6909893146',
#  '用户6909989062',
#  '用户6731550940',
#  '用户1275819459',
#  '用户6644481368',
#  '用户6640489191',
#  '用户6910813024',
#  '用户6609949238',
#  '用户6910108927',
#  '用户6597476627',
#  '用户6637906121',
#  '用户6942303688',
#  '用户6861909724',
#  '用户6606014755',
#  '用户4332331901',
#  '用户6595131151',
#  '用户6578846885',
#  '用户6601311079',
#  '用户6596767475',
#  '用户6618780085',
#  '用户6619279824',
#  '用户6618778723',
#  '用户6825431710',
#  '用户6618781133',
#  '用户6609778071',
#  '用户6741913667',
#  '用户6919876349',
#  '用户6599692700',
#  '用户6603022863',
#  '用户6825374791',
#  '用户6912548707',
#  '用户6654010984',
#  '用户6654615616',
#  '用户6765387890',
#  '用户6828649157',
#  '用户6827429814',
#  '用户6742814114',
#  '用户6918514901',
#  '用户6715246929',
#  '用户6741992925',
#  '用户6883316860',
#  '用户6883899441',
#  '用户6828424807',
#  '用户6647237400',
#  '用户6912477437',
#  '用户6500326079',
#  '用户6609351835',
#  '用户6736033355',
#  '用户6911190133',
#  '用户6606500557',
#  '用户6597509127',
#  '用户6732595474',
#  '用户6739871715',
#  '用户6606628795',
#  '用户6744566091',
#  '用户6744570643',
#  '用户6744411807',
#  '用户6827892935',
#  '用户6661339720',
#  '用户6920779139',
#  '用户6827249478',
#  '用户6646054075',
#  '用户6920789707',
#  '用户6920779168',
#  '用户6911822444',
#  '用户6606600578',
#  '用户6827915835',
#  '用户6732516055',
#  '用户6646040998',
#  '用户6911834590',
#  '用户6646546106',
#  '用户6577782283']

# %%
z_fake = z[((z['follows_num']<=5)|(z['fans_num']<=5))&
                 (z['birthday'].isna())&
                 (z['city'].isna())&
                (z['sentiment'].isna())&
                (z['sex_orientation'].isna())&
                (z['brief_introduction'].isna())].copy()
z_fake.drop_duplicates(inplace=True)
z_fake.shape
# Out:
# (145, 17)

# %%
z_fake = list(z_fake['nick_name'].unique())
z_fake
# Out:
# ['用户6900763324',
#  '绝美耀文25576',
#  '天宇可爱36611',
#  '暖男坤哥73006',
#  '用户6910108534',
#  '用户6660880069',
#  '刈其楚言tT3627',
#  '用户6919882792',
#  '用户6909893146',
#  '用户6909989062',
#  '用户1275819459',
#  '用户6644481368',
#  '用户6640489191',
#  '用户6910813024',
#  '用户6609949238',
#  '用户6910108927',
#  '用户6597476627',
#  '用户6637906121',
#  '用户6942303688',
#  '用户6606014755',
#  '用户4332331901',
#  '用户6595131151',
#  '用户6578846885',
#  '用户6609778071',
#  '用户6919876349',
#  '热血难凉筱1995',
#  '用户6603022863',
#  '用户6912548707',
#  '用户6654010984',
#  '用户6654615616',
#  '用户6918514901',
#  '用户6647237400',
#  '用户6912477437',
#  '用户6500326079',
#  '用户6609351835',
#  '用户6911190133',
#  '用户6606500557',
#  '用户6597509127',
#  '用户6606628795',
#  '向上向善Ny',
#  '用户6661339720',
#  '用户6920779139',
#  '至真至纯霜玢1997灬',
#  '用户6646054075',
#  '用户6920789707',
#  '用户6920779168',
#  '用户6911822444',
#  '单恋detective020',
#  '用户6606600578',
#  '用户6646040998',
#  'N3丶盐',
#  '用户6911834590',
#  '用户6646546106',
#  '用户6577782283',
#  '至纯至真丶HW']

# %%
z_digit = z[z['nick_name'].str.contains(r'\d+$', na=False)].copy().drop_duplicates()
z_digit.shape
# Out:
# (367, 17)

# %%
z_digit = list(z_digit['nick_name'].unique())
z_digit
# Out:
# ['用户6751917874',
#  '用户6750984191',
#  '用户6751965975',
#  '用户6751021484',
#  '心兴星7',
#  'SHAN92808',
#  '用户6736814689',
#  '无去处8',
#  '秋雨梧桐86_507',
#  '用户6900763324',
#  '用户6765418070',
#  '用户6827930453',
#  '绝美耀文25576',
#  '天宇可爱36611',
#  '暖男坤哥73006',
#  '用户6910108534',
#  '霸王龙LX1007',
#  '爱到这72070',
#  '用户6828412357',
#  '坚持98832',
#  '麻婆豆腐35085',
#  '催眠术08417',
#  '小葫芦sohappy12968',
#  '快门回溯30895',
#  '用户6660880069',
#  '相55555',
#  '用户6883315543',
#  'constraint200007',
#  '用户6743016204',
#  '用户6825553246',
#  '用户6739943318',
#  '用户6730618127',
#  '用户6828508506',
#  '刈其楚言tT3627',
#  '用户6825485780',
#  '用户6919882792',
#  '用户6909893146',
#  '望兴1007',
#  '用户6909989062',
#  '望兴19911007',
#  '用户6731550940',
#  '独角兔子10',
#  '用户1275819459',
#  '如果当初的我勇敢qj86',
#  '用户6644481368',
#  '用户6640489191',
#  '用户6910813024',
#  '用户6609949238',
#  '用户6910108927',
#  '人蕾动1007',
#  'Tattoo107',
#  '集结号168',
#  '集结号107',
#  '用户6597476627',
#  '用户6637906121',
#  '用户6942303688',
#  'magnitude201003',
#  'tar097',
#  'noted200406',
#  '用户6861909724',
#  '用户6606014755',
#  '蜡笔x坨107',
#  '用户4332331901',
#  '用户6595131151',
#  '用户6578846885',
#  '用户6601311079',
#  '用户6596767475',
#  '用户6618780085',
#  '用户6619279824',
#  '用户6618778723',
#  '用户6825431710',
#  '约定哦0710',
#  '用户6618781133',
#  '用户6609778071',
#  '用户6741913667',
#  '用户6919876349',
#  '热血难凉筱1995',
#  '用户6599692700',
#  '用户6603022863',
#  '用户6825374791',
#  '用户6912548707',
#  '用户6654010984',
#  '用户6654615616',
#  '用户6765387890',
#  '用户6828649157',
#  '用户6827429814',
#  '用户6742814114',
#  '用户6918514901',
#  '用户6715246929',
#  '用户6741992925',
#  '用户6883316860',
#  '用户6883899441',
#  '用户6828424807',
#  '用户6647237400',
#  '用户6912477437',
#  '用户6500326079',
#  '用户6609351835',
#  '用户6736033355',
#  '用户6911190133',
#  '用户6606500557',
#  '用户6597509127',
#  '用户6732595474',
#  '径庞云乃贸279',
#  '用户6739871715',
#  '初兴0213',
#  '用户6606628795',
#  '用户6744566091',
#  '用户6744570643',
#  '用户6744411807',
#  '用户6827892935',
#  '用户6661339720',
#  '用户6920779139',
#  '用户6827249478',
#  '用户6646054075',
#  '用户6920789707',
#  '用户6920779168',
#  '房径矣梅潭789',
#  '用户6911822444',
#  '单恋detective020',
#  '食蛊北逃壕686',
#  '用户6606600578',
#  '用户6827915835',
#  '用户6732516055',
#  '用户6646040998',
#  '用户6911834590',
#  '用户6646546106',
#  '用户6577782283',
#  '唯兴美865']

# %%
charlist = list(set('（亻彳讠饣艹丶乛亠冖宀冫丷扌氵灬丨亅丿乚勹匚冂凵爫礻钅廴辶犭卩刂阝疒纟丬忄飠釒糹歺虍耂牜癶夂覀罒衤亅乛乁乀）（卐彡乄冫）（亻彳讠饣艹丶乛亠冖宀冫丷扌氵灬丨亅丿乚勹匚冂凵爫礻钅廴辶犭卩刂阝疒纟丬忄飠釒糹歺虍耂牜癶夂覀罒衤亅乛乁乀）（卐彡乄冫）'))
pprint(charlist)
# Out:
# ['廴',
#  '（',
#  '宀',
#  '釒',
#  '乀',
#  '夂',
#  '疒',
#  '钅',
#  '丶',
#  '歺',
#  '彡',
#  '乚',
#  '饣',
#  '）',
#  '耂',
#  '卩',
#  '癶',
#  '礻',
#  '丨',
#  '讠',
#  '灬',
#  '辶',
#  '刂',
#  '匚',
#  '氵',
#  '艹',
#  '丿',
#  '冖',
#  '衤',
#  '卐',
#  '冂',
#  '纟',
#  '乄',
#  '扌',
#  '覀',
#  '虍',
#  '飠',
#  '丷',
#  '乁',
#  '犭',
#  '亠',
#  '彳',
#  '阝',
#  '丬',
#  '忄',
#  '凵',
#  '罒',
#  '勹',
#  '牜',
#  '乛',
#  '亻',
#  '亅',
#  '糹',
#  '冫',
#  '爫']

# %%
z_chi_char = []
for c in charlist:
    tmp = z[z['nick_name'].str.contains(c, na=False)].copy().drop_duplicates()
    names = list(tmp['nick_name'].unique())
    z_chi_char += names
z_chi_char = list(set(z_chi_char))
z_chi_char
# Out:
# ['前运颇股劫灬',
#  '至纯至真灬Lattimore',
#  'N3丶盐',
#  'LQ温润如玉丶',
#  '大大大大大大大迷糊丶',
#  '至真至纯霜玢1997灬',
#  '至纯至真丶HW',
#  '霞-罒-罒-',
#  '十号少年FR丶']

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
z_eng_char = list(z.loc[z['nick_name'].map(lambda v: any(char in v for char in string.punctuation)), 'nick_name'].unique())
z_eng_char      
#       ['nick_name', 'fans_num', 'follows_num', 'tweets_num', 'vip_level', 'brief_introduction', 'repost_device']].drop_duplicates()
# Out:
# ['xback-艺兴一意只为你',
#  'X-back在水一方',
#  'AutumnM_xback',
#  '和b_TuttiMay',
#  '宓e_lhwant',
#  '木_南街',
#  'Xback_cindy苏苏',
#  'Monologue-Lay',
#  'xback-sasha',
#  '霞-罒-罒-',
#  '秋雨梧桐86_507',
#  '恩恩恩兴L_XBack',
#  '和平的平--春晓的晓',
#  'healing_unicorn_',
#  'Xback-TX',
#  'Ling1007-紫海城洛灵兮',
#  'PRETTYIXING-',
#  '冷小姐_L',
#  '啾_咪Y',
#  'YIiiw_',
#  'Xback_YUSA的欺诈银狐',
#  '巢m_gyhq',
#  '辣椒炒肉Bd_',
#  '蕏瘢哋洊茬_kmwc',
#  '-SHARPAYyyyy',
#  'ss199212138-',
#  '南风__life',
#  'Xback_ivy',
#  'Monkey欧巴_',
#  '嫣然_AmiJk',
#  '雅痞_wxtwr',
#  '雨落流殇_amgclx',
#  '符f_MonicaMi',
#  'ISSING-XBACK',
#  '简简单单_xback',
#  '岁月无声也让人害怕-xss',
#  '毛of_UVICFiona',
#  '砷陕_dtffzm',
#  'Xback-颖',
#  '南巷_zuopiezi',
#  '余q_michiko',
#  '从s_ViviNeil',
#  '真的太甜-',
#  '国际人渣_SexKou',
#  '拥暖如初_dedienr',
#  '巴黎左岸_getwayp',
#  '隐藏所有情绪_',
#  '别怼我_我怂',
#  'YSJ-GM',
#  '属于我们的秘密_甜兴']

# %%
z_names = list(set(z_yonghu + z_fake + z_digit + z_chi_char + z_eng_char))
len(z_names)
# Out:
# 186

# %%
# ============================================ other
z.loc[z['nick_name'].isin(z_yonghu), 'birthday'].value_counts()
# Out:
# 1969-03-07    160
# 1979-06-13    140
# 2014-02-20    102
# 1989-09-19     96
# 2005-12-15     73
# 1960-01-01     48
# 1994-10-23     44
# 2012-02-13     36
# 2007-04-10     35
# 2004-01-21     34
# 2005-01-05     30
# 2004-02-05     27
# 1966-02-05     25
# 1992-10-22     24
# 2003-10-07     23
# 2013-01-28     21
# 2010-04-08     12
# 1965-02-04     10
# 1997-09-25      9
# 2013-02-13      7
# 1995-07-19      7
# 1994-10-22      6
# 1999-12-04      5
# 1967-03-05      5
# 2008-03-13      4
# 2001-02-22      4
# 2009-11-05      4
# 2006-04-14      2
# 1983-07-16      1
# 2016-06-23      1
# 1996-04-05      1
# 1999-03-08      1
# Name: birthday, dtype: int64

# %%
z[z['birthday'].str.contains('^201', na=False)]
# Out:
#             _id_x authentication    birthday brief_introduction city  \
# 12     6751021484            NaN  2016-06-23                NaN   贺州
# 186    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 187    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 189    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 191    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 193    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 195    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 197    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 199    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 201    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 203    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 205    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 207    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 208    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 209    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 211    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 213    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 215    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 217    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 219    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 221    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 223    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 225    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 227    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 229    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 231    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 233    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 235    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 237    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# 239    5253754956            NaN  2016-07-01     Bi 尊重    勿忘初心…  NaN
# ...           ...            ...         ...                ...  ...
# 11190  6742814114            NaN  2014-02-20                NaN   厦门
# 11192  6742814114            NaN  2014-02-20                NaN   厦门
# 11194  6742814114            NaN  2014-02-20                NaN   厦门
# 11196  6742814114            NaN  2014-02-20                NaN   厦门
# 11198  6742814114            NaN  2014-02-20                NaN   厦门
# 11200  6742814114            NaN  2014-02-20                NaN   厦门
# 11202  6742814114            NaN  2014-02-20                NaN   厦门
# 11204  6742814114            NaN  2014-02-20                NaN   厦门
# 11206  6742814114            NaN  2014-02-20                NaN   厦门
# 11208  6742814114            NaN  2014-02-20                NaN   厦门
# 11210  6742814114            NaN  2014-02-20                NaN   厦门
# 12519  6732595474            NaN  2013-02-13                NaN  NaN
# 12520  6732595474            NaN  2013-02-13                NaN  NaN
# 12522  6732595474            NaN  2013-02-13                NaN  NaN
# 12524  6732595474            NaN  2013-02-13                NaN  NaN
# 12526  6732595474            NaN  2013-02-13                NaN  NaN
# 12528  6732595474            NaN  2013-02-13                NaN  NaN
# 12530  6732595474            NaN  2013-02-13                NaN  NaN
# 12778  6744570643            NaN  2010-04-08                NaN   其他
# 12779  6744570643            NaN  2010-04-08                NaN   其他
# 12781  6744570643            NaN  2010-04-08                NaN   其他
# 12783  6744570643            NaN  2010-04-08                NaN   其他
# 12785  6744570643            NaN  2010-04-08                NaN   其他
# 12787  6744570643            NaN  2010-04-08                NaN   其他
# 12789  6744570643            NaN  2010-04-08                NaN   其他
# 12791  6744570643            NaN  2010-04-08                NaN   其他
# 12793  6744570643            NaN  2010-04-08                NaN   其他
# 12795  6744570643            NaN  2010-04-08                NaN   其他
# 12797  6744570643            NaN  2010-04-08                NaN   其他
# 12799  6744570643            NaN  2010-04-08                NaN   其他
#
#        fans_num  follows_num gender labels     nick_name province sentiment  \
# 12          1.0          0.0      女    NaN  用户6751021484       广西       NaN
# 186        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 187        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 189        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 191        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 193        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 195        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 197        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 199        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 201        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 203        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 205        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 207        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 208        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 209        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 211        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 213        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 215        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 217        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 219        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 221        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 223        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 225        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 227        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 229        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 231        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 233        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 235        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 237        84.0        156.0      女    NaN          心兴星7       其他       NaN
# 239        84.0        156.0      女    NaN          心兴星7       其他       NaN
# ...         ...          ...    ...    ...           ...      ...       ...
# 11190       1.0          0.0      男    NaN  用户6742814114       福建       NaN
# 11192       1.0          0.0      男    NaN  用户6742814114       福建       NaN
# 11194       1.0          0.0      男    NaN  用户6742814114       福建       NaN
# 11196       1.0          0.0      男    NaN  用户6742814114       福建       NaN
# 11198       1.0          0.0      男    NaN  用户6742814114       福建       NaN
# 11200       1.0          0.0      男    NaN  用户6742814114       福建       NaN
# 11202       1.0          0.0      男    NaN  用户6742814114       福建       NaN
# 11204       1.0          0.0      男    NaN  用户6742814114       福建       NaN
# 11206       1.0          0.0      男    NaN  用户6742814114       福建       NaN
# 11208       1.0          0.0      男    NaN  用户6742814114       福建       NaN
# 11210       1.0          0.0      男    NaN  用户6742814114       福建       NaN
# 12519       1.0          0.0      男    NaN  用户6732595474       重庆       NaN
# 12520       1.0          0.0      男    NaN  用户6732595474       重庆       NaN
# 12522       1.0          0.0      男    NaN  用户6732595474       重庆       NaN
# 12524       1.0          0.0      男    NaN  用户6732595474       重庆       NaN
# 12526       1.0          0.0      男    NaN  用户6732595474       重庆       NaN
# 12528       1.0          0.0      男    NaN  用户6732595474       重庆       NaN
# 12530       1.0          0.0      男    NaN  用户6732595474       重庆       NaN
# 12778       1.0          0.0      女    NaN  用户6744570643       香港       NaN
# 12779       1.0          0.0      女    NaN  用户6744570643       香港       NaN
# 12781       1.0          0.0      女    NaN  用户6744570643       香港       NaN
# 12783       1.0          0.0      女    NaN  用户6744570643       香港       NaN
# 12785       1.0          0.0      女    NaN  用户6744570643       香港       NaN
# 12787       1.0          0.0      女    NaN  用户6744570643       香港       NaN
# 12789       1.0          0.0      女    NaN  用户6744570643       香港       NaN
# 12791       1.0          0.0      女    NaN  用户6744570643       香港       NaN
# 12793       1.0          0.0      女    NaN  用户6744570643       香港       NaN
# 12795       1.0          0.0      女    NaN  用户6744570643       香港       NaN
# 12797       1.0          0.0      女    NaN  用户6744570643       香港       NaN
# 12799       1.0          0.0      女    NaN  用户6744570643       香港       NaN
#
#       sex_orientation  tweets_num vip_level  \
# 12                NaN        49.0       未开通
# 186               NaN     21781.0       未开通
# 187               NaN     21781.0       未开通
# 189               NaN     21781.0       未开通
# 191               NaN     21781.0       未开通
# 193               NaN     21781.0       未开通
# 195               NaN     21781.0       未开通
# 197               NaN     21781.0       未开通
# 199               NaN     21781.0       未开通
# 201               NaN     21781.0       未开通
# 203               NaN     21781.0       未开通
# 205               NaN     21781.0       未开通
# 207               NaN     21781.0       未开通
# 208               NaN     21781.0       未开通
# 209               NaN     21781.0       未开通
# 211               NaN     21781.0       未开通
# 213               NaN     21781.0       未开通
# 215               NaN     21781.0       未开通
# 217               NaN     21781.0       未开通
# 219               NaN     21781.0       未开通
# 221               NaN     21781.0       未开通
# 223               NaN     21781.0       未开通
# 225               NaN     21781.0       未开通
# 227               NaN     21781.0       未开通
# 229               NaN     21781.0       未开通
# 231               NaN     21781.0       未开通
# 233               NaN     21781.0       未开通
# 235               NaN     21781.0       未开通
# 237               NaN     21781.0       未开通
# 239               NaN     21781.0       未开通
# ...               ...         ...       ...
# 11190             NaN        47.0       未开通
# 11192             NaN        47.0       未开通
# 11194             NaN        47.0       未开通
# 11196             NaN        47.0       未开通
# 11198             NaN        47.0       未开通
# 11200             NaN        47.0       未开通
# 11202             NaN        47.0       未开通
# 11204             NaN        47.0       未开通
# 11206             NaN        47.0       未开通
# 11208             NaN        47.0       未开通
# 11210             NaN        47.0       未开通
# 12519             NaN       260.0       未开通
# 12520             NaN       260.0       未开通
# 12522             NaN       260.0       未开通
# 12524             NaN       260.0       未开通
# 12526             NaN       260.0       未开通
# 12528             NaN       260.0       未开通
# 12530             NaN       260.0       未开通
# 12778             NaN        50.0       未开通
# 12779             NaN        50.0       未开通
# 12781             NaN        50.0       未开通
# 12783             NaN        50.0       未开通
# 12785             NaN        50.0       未开通
# 12787             NaN        50.0       未开通
# 12789             NaN        50.0       未开通
# 12791             NaN        50.0       未开通
# 12793             NaN        50.0       未开通
# 12795             NaN        50.0       未开通
# 12797             NaN        50.0       未开通
# 12799             NaN        50.0       未开通
#
#                                                  content  repost_device
# 12             用户6751021484: 赞[0] 03月03日 22:49 来自Android      来自Android
# 186    心兴星7://@UnicornLay_张艺兴打榜基地:#制作人张艺兴# #张艺兴出席格莱美颁...  来自 iPhone客户端
# 187                                            返回心兴星7的微博            NaN
# 189                                            返回心兴星7的微博            NaN
# 191                                            返回心兴星7的微博            NaN
# 193                                            返回心兴星7的微博            NaN
# 195                                            返回心兴星7的微博            NaN
# 197                                            返回心兴星7的微博            NaN
# 199                                            返回心兴星7的微博            NaN
# 201                                            返回心兴星7的微博            NaN
# 203                                            返回心兴星7的微博            NaN
# 205                                            返回心兴星7的微博            NaN
# 207                                            返回心兴星7的微博            NaN
# 208                                            返回心兴星7的微博            NaN
# 209                                            返回心兴星7的微博            NaN
# 211                                            返回心兴星7的微博            NaN
# 213                                            返回心兴星7的微博            NaN
# 215                                            返回心兴星7的微博            NaN
# 217                                            返回心兴星7的微博            NaN
# 219                                            返回心兴星7的微博            NaN
# 221                                            返回心兴星7的微博            NaN
# 223                                            返回心兴星7的微博            NaN
# 225                                            返回心兴星7的微博            NaN
# 227                                            返回心兴星7的微博            NaN
# 229                                            返回心兴星7的微博            NaN
# 231                                            返回心兴星7的微博            NaN
# 233                                            返回心兴星7的微博            NaN
# 235                                            返回心兴星7的微博            NaN
# 237                                            返回心兴星7的微博            NaN
# 239                                            返回心兴星7的微博            NaN
# ...                                                  ...            ...
# 11190                                  返回用户6742814114的微博            NaN
# 11192                                  返回用户6742814114的微博            NaN
# 11194                                  返回用户6742814114的微博            NaN
# 11196                                  返回用户6742814114的微博            NaN
# 11198                                  返回用户6742814114的微博            NaN
# 11200                                  返回用户6742814114的微博            NaN
# 11202                                  返回用户6742814114的微博            NaN
# 11204                                  返回用户6742814114的微博            NaN
# 11206                                  返回用户6742814114的微博            NaN
# 11208                                  返回用户6742814114的微博            NaN
# 11210                                  返回用户6742814114的微博            NaN
# 12519  用户6732595474://@奶了吧唧的小仙女:陪你等到愿望成真的那一天//@努力努力再努...      来自Android
# 12520                                  返回用户6732595474的微博            NaN
# 12522                                  返回用户6732595474的微博            NaN
# 12524                                  返回用户6732595474的微博            NaN
# 12526                                  返回用户6732595474的微博            NaN
# 12528                                  返回用户6732595474的微博            NaN
# 12530                                  返回用户6732595474的微博            NaN
# 12778  用户6744570643://@Xbcak_GMM:19-2-11-4 赞[0] 02月11...      来自Android
# 12779                                  返回用户6744570643的微博            NaN
# 12781                                  返回用户6744570643的微博            NaN
# 12783                                  返回用户6744570643的微博            NaN
# 12785                                  返回用户6744570643的微博            NaN
# 12787                                  返回用户6744570643的微博            NaN
# 12789                                  返回用户6744570643的微博            NaN
# 12791                                  返回用户6744570643的微博            NaN
# 12793                                  返回用户6744570643的微博            NaN
# 12795                                  返回用户6744570643的微博            NaN
# 12797                                  返回用户6744570643的微博            NaN
# 12799                                  返回用户6744570643的微博            NaN
#
# [582 rows x 17 columns]

# %%
z_bd = list(z.loc[z['birthday'].str.contains('^201', na=False), 'nick_name'].unique())
len(z_bd)
# Out:
# 13

# %%
z[((z['content'].str.contains('^返回')) | (z['content'].str.contains('//'))) 
                                           & (z['brief_introduction'].isna())]
# Out:
#             _id_x authentication    birthday brief_introduction city  \
# 8      6751917874            NaN  1999-12-04                NaN  新加坡
# 36     5699804869            NaN         NaN                NaN   其他
# 37     5699804869            NaN         NaN                NaN   其他
# 95     5856130264            NaN         处女座                NaN  NaN
# 141    6222795155            NaN         NaN                NaN  NaN
# 142    6222795155            NaN         NaN                NaN  NaN
# 144    6222795155            NaN         NaN                NaN  NaN
# 146    6222795155            NaN         NaN                NaN  NaN
# 148    6222795155            NaN         NaN                NaN  NaN
# 150    6222795155            NaN         NaN                NaN  NaN
# 152    6222795155            NaN         NaN                NaN  NaN
# 154    6222795155            NaN         NaN                NaN  NaN
# 156    6222795155            NaN         NaN                NaN  NaN
# 158    6222795155            NaN         NaN                NaN  NaN
# 160    6222795155            NaN         NaN                NaN  NaN
# 162    6222795155            NaN         NaN                NaN  NaN
# 164    6222795155            NaN         NaN                NaN  NaN
# 166    6222795155            NaN         NaN                NaN  NaN
# 168    6222795155            NaN         NaN                NaN  NaN
# 170    6222795155            NaN         NaN                NaN  NaN
# 172    6222795155            NaN         NaN                NaN  NaN
# 174    6222795155            NaN         NaN                NaN  NaN
# 176    6222795155            NaN         NaN                NaN  NaN
# 178    6222795155            NaN         NaN                NaN  NaN
# 180    6222795155            NaN         NaN                NaN  NaN
# 182    6222795155            NaN         NaN                NaN  NaN
# 184    6222795155            NaN         NaN                NaN  NaN
# 243    6900750246            NaN  1995-07-19                NaN  NaN
# 244    6900750246            NaN  1995-07-19                NaN  NaN
# 246    6900750246            NaN  1995-07-19                NaN  NaN
# ...           ...            ...         ...                ...  ...
# 13987  6744338669            NaN         NaN                NaN  NaN
# 13989  6744338669            NaN         NaN                NaN  NaN
# 13991  6744338669            NaN         NaN                NaN  NaN
# 13993  6911834590            NaN         NaN                NaN  NaN
# 13994  6911834590            NaN         NaN                NaN  NaN
# 13996  6911834590            NaN         NaN                NaN  NaN
# 13998  6911834590            NaN         NaN                NaN  NaN
# 14000  6911834590            NaN         NaN                NaN  NaN
# 14002  6911834590            NaN         NaN                NaN  NaN
# 14004  6646546106            NaN         NaN                NaN  NaN
# 14005  6577782283            NaN         NaN                NaN  NaN
# 14006  6577782283            NaN         NaN                NaN  NaN
# 14008  6577782283            NaN         NaN                NaN  NaN
# 14010  6577782283            NaN         NaN                NaN  NaN
# 14012  6577782283            NaN         NaN                NaN  NaN
# 14014  6577782283            NaN         NaN                NaN  NaN
# 14016  6577782283            NaN         NaN                NaN  NaN
# 14018  6577782283            NaN         NaN                NaN  NaN
# 14020  6577782283            NaN         NaN                NaN  NaN
# 14022  6577782283            NaN         NaN                NaN  NaN
# 14024  6577782283            NaN         NaN                NaN  NaN
# 14026  6577782283            NaN         NaN                NaN  NaN
# 14028  6577782283            NaN         NaN                NaN  NaN
# 14030  6577782283            NaN         NaN                NaN  NaN
# 14032  6577782283            NaN         NaN                NaN  NaN
# 14034  6577782283            NaN         NaN                NaN  NaN
# 14036  6577782283            NaN         NaN                NaN  NaN
# 14038  6577782283            NaN         NaN                NaN  NaN
# 14041  6737160061            NaN         NaN                NaN  NaN
# 14042  6737160061            NaN         NaN                NaN  NaN
#
#        fans_num  follows_num gender labels     nick_name province sentiment  \
# 8           1.0          0.0      女    NaN  用户6751917874       海外       NaN
# 36        177.0        167.0      女    NaN    X-back在水一方       台湾       NaN
# 37        177.0        167.0      女    NaN    X-back在水一方       台湾       NaN
# 95        130.0        198.0      女    NaN          紫韵成风       其他       NaN
# 141       110.0        165.0      男    NaN           绿地都       四川       NaN
# 142       110.0        165.0      男    NaN           绿地都       四川       NaN
# 144       110.0        165.0      男    NaN           绿地都       四川       NaN
# 146       110.0        165.0      男    NaN           绿地都       四川       NaN
# 148       110.0        165.0      男    NaN           绿地都       四川       NaN
# 150       110.0        165.0      男    NaN           绿地都       四川       NaN
# 152       110.0        165.0      男    NaN           绿地都       四川       NaN
# 154       110.0        165.0      男    NaN           绿地都       四川       NaN
# 156       110.0        165.0      男    NaN           绿地都       四川       NaN
# 158       110.0        165.0      男    NaN           绿地都       四川       NaN
# 160       110.0        165.0      男    NaN           绿地都       四川       NaN
# 162       110.0        165.0      男    NaN           绿地都       四川       NaN
# 164       110.0        165.0      男    NaN           绿地都       四川       NaN
# 166       110.0        165.0      男    NaN           绿地都       四川       NaN
# 168       110.0        165.0      男    NaN           绿地都       四川       NaN
# 170       110.0        165.0      男    NaN           绿地都       四川       NaN
# 172       110.0        165.0      男    NaN           绿地都       四川       NaN
# 174       110.0        165.0      男    NaN           绿地都       四川       NaN
# 176       110.0        165.0      男    NaN           绿地都       四川       NaN
# 178       110.0        165.0      男    NaN           绿地都       四川       NaN
# 180       110.0        165.0      男    NaN           绿地都       四川       NaN
# 182       110.0        165.0      男    NaN           绿地都       四川       NaN
# 184       110.0        165.0      男    NaN           绿地都       四川       NaN
# 243         1.0         64.0      女    NaN   和b_TuttiMay       广东       NaN
# 244         1.0         64.0      女    NaN   和b_TuttiMay       广东       NaN
# 246         1.0         64.0      女    NaN   和b_TuttiMay       广东       NaN
# ...         ...          ...    ...    ...           ...      ...       ...
# 13987       1.0          0.0      女    NaN          N3丶盐       宁夏       NaN
# 13989       1.0          0.0      女    NaN          N3丶盐       宁夏       NaN
# 13991       1.0          0.0      女    NaN          N3丶盐       宁夏       NaN
# 13993       1.0          0.0      男    NaN  用户6911834590       其他       NaN
# 13994       1.0          0.0      男    NaN  用户6911834590       其他       NaN
# 13996       1.0          0.0      男    NaN  用户6911834590       其他       NaN
# 13998       1.0          0.0      男    NaN  用户6911834590       其他       NaN
# 14000       1.0          0.0      男    NaN  用户6911834590       其他       NaN
# 14002       1.0          0.0      男    NaN  用户6911834590       其他       NaN
# 14004       1.0          1.0      男    NaN  用户6646546106       其他       NaN
# 14005       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14006       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14008       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14010       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14012       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14014       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14016       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14018       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14020       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14022       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14024       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14026       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14028       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14030       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14032       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14034       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14036       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14038       1.0          0.0      男    NaN  用户6577782283       其他       NaN
# 14041       1.0          0.0      男    NaN       至纯至真丶HW       海南       NaN
# 14042       1.0          0.0      男    NaN       至纯至真丶HW       海南       NaN
#
#       sex_orientation  tweets_num vip_level  \
# 8                 NaN        54.0       未开通
# 36                NaN     58187.0       未开通
# 37                NaN     58187.0       未开通
# 95                NaN      2924.0       未开通
# 141               NaN     13700.0       未开通
# 142               NaN     13700.0       未开通
# 144               NaN     13700.0       未开通
# 146               NaN     13700.0       未开通
# 148               NaN     13700.0       未开通
# 150               NaN     13700.0       未开通
# 152               NaN     13700.0       未开通
# 154               NaN     13700.0       未开通
# 156               NaN     13700.0       未开通
# 158               NaN     13700.0       未开通
# 160               NaN     13700.0       未开通
# 162               NaN     13700.0       未开通
# 164               NaN     13700.0       未开通
# 166               NaN     13700.0       未开通
# 168               NaN     13700.0       未开通
# 170               NaN     13700.0       未开通
# 172               NaN     13700.0       未开通
# 174               NaN     13700.0       未开通
# 176               NaN     13700.0       未开通
# 178               NaN     13700.0       未开通
# 180               NaN     13700.0       未开通
# 182               NaN     13700.0       未开通
# 184               NaN     13700.0       未开通
# 243               NaN       137.0       未开通
# 244               NaN       137.0       未开通
# 246               NaN       137.0       未开通
# ...               ...         ...       ...
# 13987             NaN       493.0       未开通
# 13989             NaN       493.0       未开通
# 13991             NaN       493.0       未开通
# 13993             NaN       130.0       未开通
# 13994             NaN       130.0       未开通
# 13996             NaN       130.0       未开通
# 13998             NaN       130.0       未开通
# 14000             NaN       130.0       未开通
# 14002             NaN       130.0       未开通
# 14004             NaN       460.0       未开通
# 14005             NaN       536.0       未开通
# 14006             NaN       536.0       未开通
# 14008             NaN       536.0       未开通
# 14010             NaN       536.0       未开通
# 14012             NaN       536.0       未开通
# 14014             NaN       536.0       未开通
# 14016             NaN       536.0       未开通
# 14018             NaN       536.0       未开通
# 14020             NaN       536.0       未开通
# 14022             NaN       536.0       未开通
# 14024             NaN       536.0       未开通
# 14026             NaN       536.0       未开通
# 14028             NaN       536.0       未开通
# 14030             NaN       536.0       未开通
# 14032             NaN       536.0       未开通
# 14034             NaN       536.0       未开通
# 14036             NaN       536.0       未开通
# 14038             NaN       536.0       未开通
# 14041             NaN       450.0       未开通
# 14042             NaN       450.0       未开通
#
#                                                  content   repost_device
# 8                                      返回用户6751917874的微博             NaN
# 36     X-back在水一方://@UnicornLay_张艺兴打榜基地:#制作人张艺兴# #张艺兴...  来自 Android客户端
# 37                                       返回X-back在水一方的微博             NaN
# 95     紫韵成风://@UnicornLay_张艺兴打榜基地:#制作人张艺兴# #张艺兴出席格莱美颁...  来自海信H11 AI拍你更美
# 141    绿地都://@UnicornLay_张艺兴打榜基地:#制作人张艺兴# #张艺兴出席格莱美颁奖...    来自三星A8s黑瞳全视屏
# 142                                             返回绿地都的微博             NaN
# 144                                             返回绿地都的微博             NaN
# 146                                             返回绿地都的微博             NaN
# 148                                             返回绿地都的微博             NaN
# 150                                             返回绿地都的微博             NaN
# 152                                             返回绿地都的微博             NaN
# 154                                             返回绿地都的微博             NaN
# 156                                             返回绿地都的微博             NaN
# 158                                             返回绿地都的微博             NaN
# 160                                             返回绿地都的微博             NaN
# 162                                             返回绿地都的微博             NaN
# 164                                             返回绿地都的微博             NaN
# 166                                             返回绿地都的微博             NaN
# 168                                             返回绿地都的微博             NaN
# 170                                             返回绿地都的微博             NaN
# 172                                             返回绿地都的微博             NaN
# 174                                             返回绿地都的微博             NaN
# 176                                             返回绿地都的微博             NaN
# 178                                             返回绿地都的微博             NaN
# 180                                             返回绿地都的微博             NaN
# 182                                             返回绿地都的微博             NaN
# 184                                             返回绿地都的微博             NaN
# 243    和b_TuttiMay://@NN_Xback:梦  想  成  真 赞[0] 02月11日...       来自Android
# 244                                     返回和b_TuttiMay的微博             NaN
# 246                                     返回和b_TuttiMay的微博             NaN
# ...                                                  ...             ...
# 13987                                          返回N3丶盐的微博             NaN
# 13989                                          返回N3丶盐的微博             NaN
# 13991                                          返回N3丶盐的微博             NaN
# 13993  用户6911834590://@奶了吧唧的小仙女:陪你等到愿望成真的那一天//@努力努力再努...       来自Android
# 13994                                  返回用户6911834590的微博             NaN
# 13996                                  返回用户6911834590的微博             NaN
# 13998                                  返回用户6911834590的微博             NaN
# 14000                                  返回用户6911834590的微博             NaN
# 14002                                  返回用户6911834590的微博             NaN
# 14004  用户6646546106://@奶了吧唧的小仙女:陪你等到愿望成真的那一天//@努力努力再努...       来自Android
# 14005  用户6577782283://@奶了吧唧的小仙女:陪你等到愿望成真的那一天//@努力努力再努...       来自Android
# 14006                                  返回用户6577782283的微博             NaN
# 14008                                  返回用户6577782283的微博             NaN
# 14010                                  返回用户6577782283的微博             NaN
# 14012                                  返回用户6577782283的微博             NaN
# 14014                                  返回用户6577782283的微博             NaN
# 14016                                  返回用户6577782283的微博             NaN
# 14018                                  返回用户6577782283的微博             NaN
# 14020                                  返回用户6577782283的微博             NaN
# 14022                                  返回用户6577782283的微博             NaN
# 14024                                  返回用户6577782283的微博             NaN
# 14026                                  返回用户6577782283的微博             NaN
# 14028                                  返回用户6577782283的微博             NaN
# 14030                                  返回用户6577782283的微博             NaN
# 14032                                  返回用户6577782283的微博             NaN
# 14034                                  返回用户6577782283的微博             NaN
# 14036                                  返回用户6577782283的微博             NaN
# 14038                                  返回用户6577782283的微博             NaN
# 14041  至纯至真丶HW://@奶了吧唧的小仙女:陪你等到愿望成真的那一天//@努力努力再努力x:非常...       来自Android
# 14042                                       返回至纯至真丶HW的微博             NaN
#
# [4543 rows x 17 columns]

# %%
z_fanhui = list(z.loc[((z['content'].str.contains('^返回')) | (z['content'].str.contains('//'))) 
                                           & (z['brief_introduction'].isna()), 'nick_name'].unique())
len(z_fanhui)
# Out:
# 170

# %%
# ============================================ fake account (w/ FP) characters
z_names = list(set(z_names + z_bd + z_fanhui))
len(z_names)
# Out:
# 216

# %% [markdown]
# # ============================================ 懒得搞def

# %%
zfdf = z[z['nick_name'].isin(z_names)]
zfdf.shape
# Out:
# (5763, 17)

# %%
zfdf[zfdf.repost_device.str.contains('榜', na=False)]
# Out:
# Empty DataFrame
# Columns: [_id_x, authentication, birthday, brief_introduction, city, fans_num, follows_num, gender, labels, nick_name, province, sentiment, sex_orientation, tweets_num, vip_level, content, repost_device]
# Index: []

# %%
zfdf.vip_level.value_counts()
# Out:
# 未开通    4803
# 1级      349
# 4级      190
# 6级      152
# 5级      119
# 3级      103
# 2级       47
# Name: vip_level, dtype: int64

# %%
zfdf.loc[zfdf['tweets_num'] < 1500, ['nick_name', 'vip_level', 'fans_num', 'follows_num', 'tweets_num']]\
    .drop_duplicates()\
    .sort_values(by='tweets_num')
# Out:
#               nick_name vip_level  fans_num  follows_num  tweets_num
# 4670       用户6739943318       未开通       1.0          5.0        29.0
# 2644            巢m_gyhq       未开通       1.0         60.0        32.0
# 2811       用户6828412357       未开通       1.0          5.0        33.0
# 10         用户6750984191       未开通       1.0          0.0        36.0
# 10553      用户6765387890       未开通       1.0          0.0        39.0
# 9506       用户6825431710       未开通       1.0          0.0        46.0
# 9908       用户6741913667       未开通       1.0          0.0        47.0
# 11010      用户6742814114       未开通       1.0          0.0        47.0
# 11298      用户6741992925       未开通       1.0          0.0        48.0
# 12         用户6751021484       未开通       1.0          0.0        49.0
# 10284      用户6825374791       未开通       1.0          0.0        49.0
# 12725      用户6744566091       未开通       1.0          0.0        50.0
# 12778      用户6744570643       未开通       1.0          0.0        50.0
# 12801      用户6744411807       未开通       1.0          0.0        50.0
# 11         用户6751965975       未开通       1.0          0.0        52.0
# 4          用户6751917874       未开通       1.0          0.0        54.0
# 10607      用户6828649157       未开通       1.0          0.0        55.0
# 5734        符f_MonicaMi       未开通       5.0         52.0        55.0
# 12540      用户6739871715       未开通      10.0          9.0        58.0
# 10923      用户6827429814       未开通       1.0          0.0        59.0
# 4711       用户6730618127       未开通       1.0          5.0        61.0
# 13464        属于我们的秘密_甜兴       未开通      11.0         66.0        63.0
# 12414      用户6736033355       未开通      10.0          9.0        69.0
# 3849        品牌福兴Chester       未开通       4.0          5.0        71.0
# 1048       用户6900763324       未开通       1.0          0.0        73.0
# 11962            别怼我_我怂       未开通       9.0         64.0        78.0
# 5032       用户6919882792       未开通       1.0          0.0        89.0
# 5045       用户6909893146       未开通       1.0          0.0        95.0
# 13665      用户6911822444       未开通       1.0          0.0       100.0
# 8234       用户6942303688       未开通       1.0          0.0       122.0
# ...                 ...       ...       ...          ...         ...
# 3738       用户6660880069       未开通       1.0          0.0       521.0
# 14005      用户6577782283       未开通       1.0          0.0       536.0
# 12808            向上向善Ny       未开通       1.0          0.0       536.0
# 2596             YIiiw_        5级      76.0        143.0       543.0
# 8107       用户6597476627       未开通       1.0          0.0       549.0
# 8876       用户6595131151       未开通       1.0          0.0       566.0
# 1318                离殃渊       未开通      66.0        763.0       613.0
# 6131       用户6731550940       未开通       1.0          0.0       643.0
# 8813       用户4332331901       未开通       1.0          1.0       651.0
# 7854        南巷_zuopiezi       未开通       1.0         54.0       661.0
# 252            霸王龙的十号少年       未开通      56.0        107.0       698.0
# 8162       用户6637906121       未开通       1.0          0.0       760.0
# 6551       用户1275819459       未开通       1.0          1.0       779.0
# 6384      岁月无声也让人害怕-xss        1级      20.0         43.0       782.0
# 9703            约定哦0710       未开通      29.0        119.0       827.0
# 11304      用户6883316860       未开通      15.0         49.0       932.0
# 4459            迷路input       未开通      17.0         46.0       936.0
# 8389    magnitude201003       未开通      15.0         47.0       936.0
# 4276       用户6883315543       未开通      15.0         49.0       936.0
# 8292          金妮haughty       未开通      16.0         48.0       940.0
# 4280   constraint200007       未开通      14.0         47.0       941.0
# 2249               啾_咪Y        4级     202.0        305.0       991.0
# 11540      用户6883899441       未开通      15.0         49.0       995.0
# 4969           嫣然_AmiJk       未开通       1.0         51.0       995.0
# 8392             tar097       未开通      15.0         43.0       996.0
# 8425        noted200406       未开通      17.0         49.0       997.0
# 7863          Tattoo107       未开通      34.0         41.0      1001.0
# 7948             集结号107       未开通      67.0         70.0      1259.0
# 8054            集结号520x       未开通      64.0         65.0      1440.0
# 690         xback-sasha       未开通      33.0         90.0      1484.0
#
# [146 rows x 5 columns]

# %%
zfdf = zfdf[zfdf['tweets_num'] < 1500].copy()
len(zfdf['nick_name'].unique())
# Out:
# 146

# %%
zfdf.province.value_counts()
# Out:
# 其他     1499
# 海外      464
# 山东      231
# 海南      162
# 北京      156
# 浙江      148
# 吉林      146
# 广东      118
# 西藏      115
# 贵州      112
# 福建      102
# 安徽      102
# 台湾       96
# 云南       95
# 江苏       91
# 甘肃       81
# 江西       72
# 辽宁       46
# 重庆       36
# 上海       35
# 澳门       34
# 青海       28
# 湖南       20
# 山西       19
# 香港       12
# 新疆        7
# 宁夏        6
# 广西        6
# 陕西        6
# 河南        5
# 内蒙古       4
# 黑龙江       3
# Name: province, dtype: int64

# %%
zfdf.head()
# Out:
#         _id_x authentication    birthday brief_introduction city  fans_num  \
# 4  6751917874            NaN  1999-12-04                NaN  新加坡       1.0
# 5  6751917874            NaN  1999-12-04                NaN  新加坡       1.0
# 6  6751917874            NaN  1999-12-04                NaN  新加坡       1.0
# 7  6751917874            NaN  1999-12-04                NaN  新加坡       1.0
# 8  6751917874            NaN  1999-12-04                NaN  新加坡       1.0
#
#    follows_num gender labels     nick_name province sentiment sex_orientation  \
# 4          0.0      女    NaN  用户6751917874       海外       NaN             NaN
# 5          0.0      女    NaN  用户6751917874       海外       NaN             NaN
# 6          0.0      女    NaN  用户6751917874       海外       NaN             NaN
# 7          0.0      女    NaN  用户6751917874       海外       NaN             NaN
# 8          0.0      女    NaN  用户6751917874       海外       NaN             NaN
#
#    tweets_num vip_level                                    content  \
# 4        54.0       未开通  用户6751917874: 赞[0] 03月03日 22:44 来自Android
# 5        54.0       未开通  用户6751917874: 赞[0] 03月03日 22:45 来自Android
# 6        54.0       未开通  用户6751917874: 赞[0] 03月03日 22:46 来自Android
# 7        54.0       未开通  用户6751917874: 赞[0] 03月03日 22:47 来自Android
# 8        54.0       未开通                          返回用户6751917874的微博
#
#   repost_device
# 4     来自Android
# 5     来自Android
# 6     来自Android
# 7     来自Android
# 8           NaN

# %%
cols = ['authentication', 'brief_introduction', 'city', 'sentiment', 'sex_orientation']
for col in cols:
    zfdf['bi_' + col] = 0
    zfdf.loc[~zfdf[col].isna(), 'bi_' + col] = 1
    print('\n====== bi_' + col)
    print(zfdf['bi_' + col].value_counts())
# Out:
# ====== bi_authentication
# 0    4057
# Name: bi_authentication, dtype: int64
#
# ====== bi_brief_introduction
# 0    3815
# 1     242
# Name: bi_brief_introduction, dtype: int64
#
# ====== bi_city
# 0    2665
# 1    1392
# Name: bi_city, dtype: int64
#
# ====== bi_sentiment
# 0    3962
# 1      95
# Name: bi_sentiment, dtype: int64
#
# ====== bi_sex_orientation
# 0    4047
# 1      10
# Name: bi_sex_orientation, dtype: int64

# %%
zfdf['bi_bd'] = 1
zfdf.loc[zfdf['birthday'].str.contains('^201', na=False), 'bi_bd'] = 0
zfdf.loc[zfdf['birthday'].isna(), 'bi_bd'] = -1
zfdf['bi_bd'].value_counts()
# Out:
# -1    2387
#  1    1491
#  0     179
# Name: bi_bd, dtype: int64

# %%
zfdf['bi_labels'] = 0
zfdf.loc[~zfdf['birthday'].isna(), 'bi_labels'] = 1
zfdf['bi_labels'].value_counts()
# Out:
# 0    2387
# 1    1670
# Name: bi_labels, dtype: int64

# %%
z['vip_level'].value_counts()
# Out:
# 未开通    5356
# 1级      527
# 3级      365
# 6级      358
# 5级      287
# 4级      222
# 2级      193
# Name: vip_level, dtype: int64

# %%
zfdf['vip_level'] = zfdf['vip_level'].map({'未开通': 0,
                       '1级': 1,
                       '2级': 2,
                       '3级': 3,
                       '4级': 4,
                       '5级': 5,
                       '6级': 6})
zfdf['vip_level'].value_counts()
# Out:
# 0    3868
# 4      95
# 1      84
# 5      10
# Name: vip_level, dtype: int64

# %%
zfdf['bi_content'] = 0
zfdf.loc[zfdf['content'].str.contains('^返回'), 'bi_content'] = 1
zfdf.loc[zfdf['content'].str.contains('//'), 'bi_content'] = 2
zfdf['bi_content'].value_counts()
# Out:
# 1    3791
# 2     259
# 0       7
# Name: bi_content, dtype: int64

# %%
zfdf['province'].value_counts()
# Out:
# 其他     1499
# 海外      464
# 山东      231
# 海南      162
# 北京      156
# 浙江      148
# 吉林      146
# 广东      118
# 西藏      115
# 贵州      112
# 福建      102
# 安徽      102
# 台湾       96
# 云南       95
# 江苏       91
# 甘肃       81
# 江西       72
# 辽宁       46
# 重庆       36
# 上海       35
# 澳门       34
# 青海       28
# 湖南       20
# 山西       19
# 香港       12
# 新疆        7
# 宁夏        6
# 广西        6
# 陕西        6
# 河南        5
# 内蒙古       4
# 黑龙江       3
# Name: province, dtype: int64

# %%
zfdf['bi_province'] = 0
zfdf.loc[((zfdf['province'] == '海外') | (zfdf['province'] == '其他')), 'bi_province'] = 1
zfdf.bi_province.value_counts()
# ============================================ fake account (w/ FP) characters
# Out:
# 0    2094
# 1    1963
# Name: bi_province, dtype: int64

# %%
zfdf.columns
# Out:
# Index(['_id_x', 'authentication', 'birthday', 'brief_introduction', 'city',
#        'fans_num', 'follows_num', 'gender', 'labels', 'nick_name', 'province',
#        'sentiment', 'sex_orientation', 'tweets_num', 'vip_level', 'content',
#        'repost_device', 'bi_authentication', 'bi_brief_introduction',
#        'bi_city', 'bi_sentiment', 'bi_sex_orientation', 'bi_bd', 'bi_labels',
#        'bi_content', 'bi_province'],
#       dtype='object')

# %%
zfdf = zfdf[['_id_x', 'fans_num', 'follows_num', 'tweets_num', 'vip_level', 'gender',
             'bi_authentication', 'bi_brief_introduction', 'bi_city', 'bi_province', 'bi_sentiment',
             'bi_sex_orientation', 'bi_bd', 'bi_labels', 'bi_content']].copy()
zfdf.drop_duplicates(inplace=True)
zfdf.to_csv('zhang_fake.csv', index=False)

# %%
zfdf.shape
# Out:
# (278, 15)

# %% [markdown]
# # ============================================ sample authentic

# %%
rauth = r[~r['nick_name'].isin(r_names)].sample(500)
zauth = z[~z['nick_name'].isin(z_names)].sample(500)
# TODO: feature engineering again...
# gender, device to bi
